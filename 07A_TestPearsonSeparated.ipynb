# %%
# CAN ONLY BE RUN AFTER NEW OUTLIER_REMOVED FILES ARE GENERATED

# %%
# import necessary packages

import pandas as pd # for working with tables
pd.options.mode.chained_assignment = None  # default = 'warn'

import os # for finding file directory with os.getcwd()

# for calculations
import numpy as np 
import math

import matplotlib.pyplot as plt # for plotting

# for plotting histogram with percentages
from matplotlib.ticker import PercentFormatter
import matplotlib.ticker as mtick

from PIL import Image # for converting plots to black-and-white

from ipynb.fs.full.MyFunctions_00 import *

# %% [markdown]
# ## Compile Table of Pearson's R Table

# %%
# read in saved mean tables
ultimate_mean_voids = read_data('ultimate_mean_VOIDS_' + 'new_' + timestamp())
# Out:
# read VOIDS_outliers_removed_new_04-11-23

# %%
ultimate_mean_voids = ultimate_mean_voids.head(100)

# %%
ultimate_mean_voids.head()
# Out:
#    object_tag  mjd_binned    mean_W1    mean_W2  mean_color    std_W1  \
# 0        75.0         5.0  14.133667  13.951697    0.181970  0.816597
# 1        75.0       195.0  14.087479  13.916177    0.171302  0.818100
# 2        75.0      1465.0  13.644400  13.466700    0.177700  0.052568
# 3        75.0      1655.0  13.584250  13.437167    0.147083  0.061251
# 4        75.0      1825.0  13.672364  13.503818    0.168545  0.078336
#
#      std_W2  std_color
# 0  0.790833   0.240681
# 1  0.795176   0.204798
# 2  0.058520   0.079880
# 3  0.124310   0.132766
# 4  0.138713   0.136840

# %%
print(np.median(ultimate_mean_voids['mean_color'].to_numpy()))
print(statistics.median(ultimate_mean_voids['mean_color']))
# Out:
# 0.11224999999999985
# 0.11224999999999985

# %%
number_voids = np.unique(ultimate_mean_voids['object_tag'])
print(len(number_voids))
# Out:
# 5

# %%
# check and save Pr table
voids_Pr = Pearson_table_separated(ultimate_mean_voids)
# print(voids_Pr)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'origin_binned'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
voids_Pr
