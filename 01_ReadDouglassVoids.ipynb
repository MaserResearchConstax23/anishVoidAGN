# %%
# Start small and save your time.

# %%
# import necessary packages

import pandas as pd # for working with tables
pd.options.mode.chained_assignment = None  # default = 'warn'

import os # for finding file directory with os.getcwd()

# for calculations
import numpy as np 
import math

import matplotlib.pyplot as plt # for plotting

# for plotting histogram with percentages
from matplotlib.ticker import PercentFormatter
import matplotlib.ticker as mtick
from matplotlib.ticker import FormatStrFormatter

from PIL import Image # for converting plots to black-and-white
from IPython.display import HTML

from ipynb.fs.full.MyFunctions_00 import *

# %%
# remove "#" at the beginning

new_voids = pd.read_table(
    '/Users/anisharadhey/AstroLocal22/NewVoidsCatalog.txt', 
    delimiter = ' ')

new_voids.head()
# Out:
#            RA       DEC  ISDSS   INED  ISIXDF  IALFALFA  IZCAT  ITWODF  \
# 0  146.714215 -1.041280      0  72212   37354        -1     -1      -1
# 1  146.628585 -0.765162      1     -1      -1        -1     -1      -1
# 2  146.631706 -0.988347      2  72132      -1        -1     -1      -1
# 3  146.934129 -0.670405      3     -1      -1        -1     -1      -1
# 4  146.963500 -0.544776      4     -1      -1        -1     -1      -1
#
#          MAG         Z  ...       SFR       sSFR  HImass  vflag   u_r_err  \
# 0  15.178774  0.021222  ...       NaN        NaN     NaN      9  0.058951
# 1  17.318521  0.064656  ... -0.621067 -11.241626     NaN      2  0.197954
# 2  18.123354  0.052654  ...       NaN        NaN     NaN      2  0.111408
# 3  17.660961  0.121270  ... -0.500000 -11.712758     NaN      9  0.224820
# 4  17.616278  0.055981  ...       NaN        NaN     NaN      2  0.244688
#
#     g_r_err  NUV_r_err  rabsmag_NSA  rabsmag_ivar_NSA  rMtoL_NSA
# ...

# %%
for col in new_voids.columns:
    print(col)
# Out:
# RA
# DEC
# ISDSS
# INED
# ISIXDF
# IALFALFA
# IZCAT
# ITWODF
# MAG
# Z
# SIZE
# RUN
# CAMCOL
# FIELD
# XPOS
# YPOS
# NSAID
# ZDIST
# SERSIC_OK
# SERSIC_B300
# SERSIC_B1000
# SERSIC_METS
# SERSIC_MASS
# XCEN
# YCEN
# PETRO_BA50
# PETRO_PHI50
# PETRO_BA90
# PETRO_PHI90
# SERSIC_N
# SERSIC_BA
# SERSIC_PHI
# AID
# PID
# PETRO_THETA
# PETRO_TH50
# PETRO_TH90
# SERSIC_TH50
# PLATE
# FIBERID
# MJD
# RACAT
# DECCAT
# ZSDSSLINE
# TILE
# PLUG_RA
# PLUG_DEC
# ELPETRO_BA
# ELPETRO_PHI
# ELPETRO_FLUX_R
# ELPETRO_FLUX_IVAR_R
# ELPETRO_THETA_R
# ELPETRO_TH50_R
# ELPETRO_TH90_R
# ELPETRO_APCORR_R
# ELPETRO_OK
# ELPETRO_MASS
# ELPETRO_B300
# ELPETRO_B1000
# ELPETRO_METS
# IN_DR7_LSS
# u_r
# g_r
# NUV_r
# index
# imc
# aimc
# cd
# conx1
# u_r_KIAS
# prmag
# BPTclass
# SFR
# sSFR
# HImass
# vflag
# u_r_err
# g_r_err
# NUV_r_err
# rabsmag_NSA
# rabsmag_ivar_NSA
# rMtoL_NSA

# %%
new_voids_cols = new_voids[['NSAID','vflag', 
                       'RA', 
                       'DEC', 
                       'PLATE', 
                       'FIBERID', 
                       'MJD',
                       'rabsmag_NSA',
                       'Z',
                       'SFR', 
                       'sSFR',
                       'BPTclass',
                       'HImass',
                       'u_r',
                       'g_r',
                       'u_r_err',
                       'g_r_err'
                      ]
                     ]

new_voids_cols.head()
# Out:
#    NSAID  vflag          RA       DEC  PLATE  FIBERID    MJD  rabsmag_NSA  \
# 0      0      9  146.714215 -1.041280    266        1  51630   -19.303656
# 1      1      2  146.628585 -0.765162    266        4  51630   -19.976496
# 2      2      2  146.631706 -0.988347    266        6  51630   -18.431812
# 3      3      9  146.934129 -0.670405    266       11  51630   -21.559162
# 4      4      2  146.963500 -0.544776    266       12  51630   -19.100992
#
#           Z       SFR       sSFR  BPTclass  HImass       u_r       g_r  \
# 0  0.021222       NaN        NaN       NaN     NaN  2.102100  0.685295
# 1  0.064656 -0.621067 -11.241626       3.0     NaN  2.617825  0.734077
# 2  0.052654       NaN        NaN       NaN     NaN  1.491590  0.491562
# 3  0.121270 -0.500000 -11.712758      -1.0     NaN  2.541950  0.812006
# 4  0.055981       NaN        NaN       NaN     NaN  1.583717  0.585251
#
#     u_r_err   g_r_err
# 0  0.058951  0.028307
# 1  0.197954  0.030950
# 2  0.111408  0.039011
# ...

# %%
new_voids_filt = new_voids_cols[(new_voids_cols['vflag'] == 1)]

new_walls_filt = new_voids_cols[(new_voids_cols['vflag'] == 0)]

# %%
new_voids_filt.head()
# Out:
#      NSAID  vflag          RA       DEC  PLATE  FIBERID    MJD  rabsmag_NSA  \
# 47      52      1  146.594503 -0.133150    266      103  51630   -18.625156
# 70      75      1  145.874464 -0.608775    266      138  51630   -20.979137
# 88      95      1  146.222266 -0.375920    266      168  51630   -20.544321
# 113    121      1  145.681110 -0.867233    266      207  51630   -21.178394
# 119    127      1  145.759730 -0.813891    266      216  51630   -20.736423
#
#             Z       SFR       sSFR  BPTclass  HImass       u_r       g_r  \
# 47   0.045652 -0.487868 -10.162451       1.0     NaN  1.015083  0.402294
# 70   0.071590  0.437294 -10.228045       2.0     NaN  1.570181  0.527512
# 88   0.067406  0.436883 -10.211826       1.0     NaN  1.867657  0.645546
# 113  0.067595 -1.141768 -12.134328       5.0     NaN  2.711828  0.698425
# 119  0.067634 -0.348571 -11.222754       4.0     NaN  2.237722  0.712046
#
#       u_r_err   g_r_err
# 47   0.170116  0.076100
# ...

# %%
new_walls_filt.head()
# Out:
#      NSAID  vflag          RA       DEC  PLATE  FIBERID    MJD  rabsmag_NSA  \
# 440    464      0  148.728855  0.188863    267      152  51608   -20.542107
# 539    570      0  147.428682  1.107487    267      362  51608   -21.410318
# 541    572      0  147.511343  1.100596    267      369  51608   -20.423737
# 545    576      0  147.561502  1.229841    267      378  51608   -21.105976
# 582    615      0  148.015821  1.148428    267      442  51608   -19.731482
#
#             Z       SFR       sSFR  BPTclass  HImass       u_r       g_r  \
# 440  0.094445  0.365831  -9.764698       1.0     NaN  1.309233  0.567883
# 539  0.098661 -0.852778 -12.150420      -1.0     NaN  2.323511  0.719944
# 541  0.093593 -1.139221 -11.910791      -1.0     NaN  3.057472  0.754032
# 545  0.098923  0.393559 -10.500205       3.0     NaN  1.843855  0.594555
# 582  0.064104 -0.719594 -11.158921       2.0     NaN  2.254469  0.692661
#
#       u_r_err   g_r_err
# 440  0.619454  0.037097
# ...

# %%
# new_voids_filt.to_csv('Files/new_voids_' + timestamp() + '.csv', index = False)

# %%
# new_walls_filt.to_csv('Files/new_walls_' + timestamp() + '.csv', index = False)

# %%
print("# new voids: " + str(len(new_voids_filt)))
print("# new walls: " + str(len(new_walls_filt)))
print("")
print("")
print("# new voids: " + str(len(new_voids_filt.dropna(subset = ['RA']))))
print("# new walls: " + str(len(new_walls_filt.dropna(subset = ['RA']))))
print("")
print("# new voids: " + str(len(new_voids_filt.dropna(subset = ['DEC']))))
print("# new walls: " + str(len(new_walls_filt.dropna(subset = ['DEC']))))
print("")
print("# new voids: " + str(len(new_voids_filt.dropna(subset = ['NSAID']))))
print("# new walls: " + str(len(new_walls_filt.dropna(subset = ['NSAID']))))
# Out:
# # new voids: 86891
# # new walls: 245778
#
#
# # new voids: 86891
# # new walls: 245778
#
# # new voids: 86891
# # new walls: 245778
#
# # new voids: 86891
# # new walls: 245778

# %%
new_voids_filt[(new_voids_filt['PLATE'] == 0) &
               (new_voids_filt['FIBERID'] == 0) &
               (new_voids_filt['MJD'] == 0)
              ]
# Out:
#          NSAID  vflag          RA        DEC  PLATE  FIBERID  MJD  \
# 584455  621971      1  110.062722  32.411376      0        0    0
# 584457  621973      1  110.356184  41.007495      0        0    0
# 584458  621974      1  110.416385  32.273352      0        0    0
# 584467  621983      1  110.803771  37.459229      0        0    0
# 584482  621999      1  111.424974  31.488778      0        0    0
# ...        ...    ...         ...        ...    ...      ...  ...
# 641350  698452      1  213.212774  -0.376779      0        0    0
# 641360  698492      1  221.384562  -0.545078      0        0    0
# 641367  698507      1  219.945702  -0.369095      0        0    0
# 641371  698517      1  219.254525  -1.072115      0        0    0
# 641392  698565      1  219.175416  -1.428426      0        0    0
#
#         rabsmag_NSA         Z  SFR  sSFR  BPTclass  HImass       u_r  \
# 584455   -19.222742  0.024894  NaN   NaN       NaN     NaN  2.149113
# ...

# %%
new_walls_filt[(new_walls_filt['PLATE'] == 0) &
               (new_walls_filt['FIBERID'] == 0) &
               (new_walls_filt['MJD'] == 0)
              ]
# Out:
#          NSAID  vflag          RA        DEC  PLATE  FIBERID  MJD  \
# 584671  622204      0  118.908627  44.192130      0        0    0
# 584684  622219      0  119.265613  22.523907      0        0    0
# 584716  622257      0  120.195931  29.747605      0        0    0
# 584722  622264      0  120.367524  27.276417      0        0    0
# 584741  622285      0  120.794194  39.906009      0        0    0
# ...        ...    ...         ...        ...    ...      ...  ...
# 641362  698495      0  220.924418  -1.083778      0        0    0
# 641372  698518      0  219.222501  -0.248246      0        0    0
# 641373  698519      0  219.206721  -0.573891      0        0    0
# 641378  698525      0  218.949277  -0.168746      0        0    0
# 641383  698539      0  218.334089   0.006571      0        0    0
#
#         rabsmag_NSA         Z  SFR  sSFR  BPTclass  HImass       u_r  \
# 584671   -19.068872  0.049474  NaN   NaN       NaN     NaN  1.301588
# ...
